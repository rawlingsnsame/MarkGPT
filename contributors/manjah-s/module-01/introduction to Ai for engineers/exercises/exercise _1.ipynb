# %%
#string
Data_set_name = "my first sample"

#interger
number_of_training_samples = 3

#float 
model_accuracy = 1.2

#boolean
training_complete = False

print(f"name: {Data_set_name} type: {type(Data_set_name)}, Number of training samples: {number_of_training_samples} type: {type(number_of_training_samples)}, completed: {training_complete} type: {type(training_complete)} ")
# Out:
# name: my first sample type: <class 'str'>, Number of training samples: 3 type: <class 'int'>, completed: False type: <class 'bool'>
